# %% [markdown]
# ## Student Name: Oguzhan Aksoy

# %% [markdown]
# # Objective

# %% [markdown]
# In the scope of this assignment, your task is to train a neural network model for face recognition.
#
# At the test time, we will provide your model with pairs of images. The images inside every pair might belong to the same person (label 0) or to the different ones (label 1). We will calculate cosine distance between the predicted descriptors (by your model) for every pair and use this distance as a score in the label classification task. The metric is TPR@FPR=0.05.

# %% [markdown]
# # Scoring Criteria
# (max 15 points, 20% of the final grade)

# %% [markdown]
# You will be awarded up to 15 points based on the performance of your model on the test dataset.
#
# - If your model outperforms the baseline (gradescope submission named "BASELINE"), you will be scored 15.
# - If your model's score X satisfies 0.5 * Y <= X <= Y, where Y is the baseline score, you will be scored (X / (0.5 * Y) - 1) * 15.
# - If your model's score is below 50% of the baseline one, you will be scored 0.
#
# Notes:
# - The primary metric for scoring your models is TPR@FPR=0.05. We also print AUROC.
# - Be aware that the platform automatically performs a pretty smart code similarity comparison. Share your solutions on your own risk of losing homework scores. We will discount the scores for the parties with the high code similarity by the factor of N, where N is the number of party members.
# - Any external sources or code used should be properly cited.
# - You can use generic pretrained (e.g., ImageNet-pretrained) neural network models, but cannot use LFW and other faces datasets-pretrained models.
# - If you (apparently) find any security leaks, exploit them at your own risk of losing homework scores. We set your Homework 2 score to 0 if we detect any sign of security leaks abuse.
# - Do not name your submission "BASELINE".

# %% [markdown]
# # Submission Guidelines
# Submit the classifier.py file along with any other necessary files for model loading.

# %% [markdown]
# - Name your script file classifier.py containing a class named Classifier. Within the __init__ method of this class, initialize the neural network; no arguments will be passed (we will call it as clf = Classifier()).
# - The class should have a method named load_model which also has no arguments and it loads the weights of your model from the file(-s) you have uploaded. Example: you uploaded model.pth along with classifier.py, your code can access this file at "/autograder/submission/model.pth". (Next, we will call clf.load_model().) Besides, if you're using PyTorch, do not forget to call self.model.eval() after loading model.
# - The class should have a method named calculate_descriptors. This method should take raw images (numpy arrays of shape (112, 112, 3)) as input and return the corresponding descriptors tensors (numpy array of shape (N, )). Here, N is the size of your descriptors, can be arbitrary; but we recommend to keep it small (e.g., 256 or 512) so that your submission will not run of RAM (6 GB).
#
# Upload (submit) your files to Homework 2 of our [MA030348 course](https://www.gradescope.com/courses/646549).
#
# You can find an example of the correct classifier.py structure (PyTorch implementation) in the course files: link.

# %% [markdown]
# # Data

# %% [markdown]
# Data
# To train the algorithm, we'll provide a train set [here](https://drive.google.com/file/d/1lHYhtP-84qrwHM7f3dDXFyYQPuIfRmqt/view) (approx. 860 MB). The train folder contains *.jpg images and labels.json file with a python dict with a correspondence "image ID: person ID".
#
# To test the algorithm, we'll use a different test set of images (classes are the same).
#
# We read all images via `skimage.io.imread` !!!

# %% [markdown]
# #The platform specifications
#
# You are provided with the following resources on Gradescope: 40 minutes of processing time, 4 CPU cores, 6 GB RAM.

# %% [markdown]
# Platform provides you with python3.11 environment (activated by default) and preinstalled pip packages we need to solve the problem: `numpy`, `scipy`, `scikit-image`, `scikit-learn`, `opencv`, `torch`, `tensorflow`, `torchvision`, `keras`, `imutils`, `timm`, `gdown`.
#
# All additional files (e.g. model weights), that you have submitted along with scripts, could be found here: "/autograder/submission/".
#
# If your model weights are larger than 100 MB, you won't be able to use direct file uploading. In this case, you can try upload your model to Google disk and then download it inside the `load_model` function via `gdown`.

# %% [markdown]
# # Solution

# %%
# %pip install pytorch-metric-learning
# %pip install faiss-gpu
# Out:
# Collecting pytorch-metric-learning
#   Downloading pytorch_metric_learning-2.3.0-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Installing collected packages: pytorch-metric-learning
# Successfully installed pytorch-metric-learning-2.3.0
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir())
if not "train" in os.listdir():
  os.system("unzip /content/drive/MyDrive/train.zip -d /content")
  print("Unzipped 'train.zip'")
else:
  print("'train' is already unzipped and in the directory")
# Out:
# ['.config', 'drive', 'sample_data']
# Unzipped 'train.zip'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

### MNIST code originally from https://github.com/pytorch/examples/blob/master/mnist/main.py ###
from torchvision import datasets, transforms

from pytorch_metric_learning import distances, losses, miners, reducers, testers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator

# %%
# MODEL FROM SEMINAR
### MNIST code originally from https://github.com/pytorch/examples/blob/master/mnist/main.py ###
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout2d(0.25)
        self.dropout2 = nn.Dropout2d(0.5)
        self.fc1 = nn.Linear(9216, 128)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        return x

# %%
### MNIST code originally from https://github.com/pytorch/examples/blob/master/mnist/main.py ###
def train(model, loss_func, mining_func, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()
        embeddings = model(data)
        indices_tuple = mining_func(embeddings, labels)
        loss = loss_func(embeddings, labels, indices_tuple)
        loss.backward()
        optimizer.step()
        if batch_idx % 20 == 0:
            print(
                "Epoch {} Iteration {}: Loss = {}, Number of mined triplets = {}".format(
                    epoch, batch_idx, loss, mining_func.num_triplets
                )
            )


### convenient function from pytorch-metric-learning ###
def get_all_embeddings(dataset, model):
    tester = testers.BaseTester()
    return tester.get_all_embeddings(dataset, model)


### compute accuracy using AccuracyCalculator from pytorch-metric-learning ###
def test(train_set, test_set, model, accuracy_calculator):
    train_embeddings, train_labels = get_all_embeddings(train_set, model)
    test_embeddings, test_labels = get_all_embeddings(test_set, model)
    train_labels = train_labels.squeeze(1)
    test_labels = test_labels.squeeze(1)
    print("Computing accuracy")
    accuracies = accuracy_calculator.get_accuracy(
        test_embeddings, test_labels, train_embeddings, train_labels, False
    )
    print("Test set accuracy (Precision@1) = {}".format(accuracies["precision_at_1"]))


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

batch_size = 128

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader
import torch
from skimage import io

with open('/content/train/labels.json', 'r') as file:
    labels = json.load(file)

train_paths = [f'/content/train/{path}.jpg' for path in labels.keys()]
train_labels = list(labels.values())

class CustomImageDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = io.imread(image_path)
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

train_dataset = CustomImageDataset(train_paths, train_labels, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2, pin_memory=True)

from torchvision.models import ResNet18_Weights

model = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, 10752)
optimizer = optim.Adam(model.parameters(), lr=0.01)
num_epochs = 3
print(f"There are {torch.cuda.device_count()} available GPUs.")

if torch.cuda.device_count() > 1:
    model = torch.nn.DataParallel(model)

model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 118MB/s]
# There are 1 available GPUs.

# %%
from tqdm.autonotebook import tqdm
import shutil

### pytorch-metric-learning stuff ###
distance = distances.CosineSimilarity()
reducer = reducers.ThresholdReducer(low=0)
loss_func = losses.TripletMarginLoss(margin=0.2, distance=distance, reducer=reducer)
mining_func = miners.TripletMarginMiner(
    margin=0.2, distance=distance, type_of_triplets="semihard"
)
accuracy_calculator = AccuracyCalculator(include=("precision_at_1",), k=1)
### pytorch-metric-learning stuff ###


for epoch in tqdm(range(1, num_epochs + 1)):
    train(model, loss_func, mining_func, device, train_loader, optimizer, epoch)
    model_filename = f'model{epoch}.pth'
    torch.save(model.state_dict(), model_filename)
    shutil.copy(f'/content/model{epoch}.pth', f'/content/drive/MyDrive/model{epoch}.pth')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1 Iteration 0: Loss = 0.14824602007865906, Number of mined triplets = 318
# Epoch 1 Iteration 20: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 40: Loss = 0.08616504818201065, Number of mined triplets = 25
# Epoch 1 Iteration 60: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 80: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 100: Loss = 0.13665682077407837, Number of mined triplets = 97
# Epoch 1 Iteration 120: Loss = 0.13404269516468048, Number of mined triplets = 92
# Epoch 1 Iteration 140: Loss = 0.12343066930770874, Number of mined triplets = 13
# Epoch 1 Iteration 160: Loss = 0.12422560155391693, Number of mined triplets = 24
# Epoch 1 Iteration 180: Loss = 0.10485595464706421, Number of mined triplets = 130
# Epoch 1 Iteration 200: Loss = 0.0875491201877594, Number of mined triplets = 19
# Epoch 1 Iteration 220: Loss = 0.12601107358932495, Number of mined triplets = 141
# Epoch 1 Iteration 240: Loss = 0.17533119022846222, Number of mined triplets = 159
# Epoch 1 Iteration 260: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 280: Loss = 0.12506259977817535, Number of mined triplets = 95
# Epoch 1 Iteration 300: Loss = 0.09991434216499329, Number of mined triplets = 26
# Epoch 1 Iteration 320: Loss = 0.10103698074817657, Number of mined triplets = 26
# Epoch 1 Iteration 340: Loss = 0.149787038564682, Number of mined triplets = 96
# Epoch 1 Iteration 360: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 380: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 400: Loss = 0.13776317238807678, Number of mined triplets = 97
# Epoch 1 Iteration 420: Loss = 0.1003415435552597, Number of mined triplets = 28
# Epoch 1 Iteration 440: Loss = 0.1990346759557724, Number of mined triplets = 3
# Epoch 1 Iteration 460: Loss = 0.1290336698293686, Number of mined triplets = 159
# Epoch 1 Iteration 480: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 500: Loss = 0.14245256781578064, Number of mined triplets = 149
# Epoch 1 Iteration 520: Loss = 0.11668647825717926, Number of mined triplets = 62
# Epoch 1 Iteration 540: Loss = 0.0, Number of mined triplets = 0
# Epoch 1 Iteration 560: Loss = 0.1212197095155716, Number of mined triplets = 207
# Epoch 1 Iteration 580: Loss = 0.10185583680868149, Number of mined triplets = 70
# Epoch 1 Iteration 600: Loss = 0.15168830752372742, Number of mined triplets = 16
# Epoch 1 Iteration 620: Loss = 0.10903717577457428, Number of mined triplets = 38
# Epoch 1 Iteration 640: Loss = 0.10791624337434769, Number of mined triplets = 141
# Epoch 1 Iteration 660: Loss = 0.1497991681098938, Number of mined triplets = 46
# Epoch 1 Iteration 680: Loss = 0.09857988357543945, Number of mined triplets = 44
# Epoch 1 Iteration 700: Loss = 0.18375852704048157, Number of mined triplets = 22
# Epoch 1 Iteration 720: Loss = 0.10746414214372635, Number of mined triplets = 75
# Epoch 1 Iteration 740: Loss = 0.10306348651647568, Number of mined triplets = 68
# Epoch 1 Iteration 760: Loss = 0.09750823676586151, Number of mined triplets = 39
# Epoch 1 Iteration 780: Loss = 0.0860675796866417, Number of mined triplets = 21
# Epoch 1 Iteration 800: Loss = 0.11321670562028885, Number of mined triplets = 19
# Epoch 1 Iteration 820: Loss = 0.09734245389699936, Number of mined triplets = 33
# Epoch 1 Iteration 840: Loss = 0.13034842908382416, Number of mined triplets = 53
# Epoch 1 Iteration 860: Loss = 0.09906547516584396, Number of mined triplets = 50
# Epoch 1 Iteration 2540: Loss = 0.12270867079496384, Number of mined triplets = 49
# Epoch 1 Iteration 2560: Loss = 0.08080282062292099, Number of mined triplets = 38
# Epoch 2 Iteration 0: Loss = 0.09885767102241516, Number of mined triplets = 83
# Epoch 2 Iteration 20: Loss = 0.11660422384738922, Number of mined triplets = 203
# Epoch 2 Iteration 40: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 60: Loss = 0.1051459014415741, Number of mined triplets = 103
# Epoch 2 Iteration 80: Loss = 0.11961577832698822, Number of mined triplets = 68
# Epoch 2 Iteration 100: Loss = 0.09711345285177231, Number of mined triplets = 54
# Epoch 2 Iteration 120: Loss = 0.12811459600925446, Number of mined triplets = 85
# Epoch 2 Iteration 140: Loss = 0.10395193845033646, Number of mined triplets = 56
# Epoch 2 Iteration 160: Loss = 0.15096047520637512, Number of mined triplets = 86
# Epoch 2 Iteration 180: Loss = 0.13435854017734528, Number of mined triplets = 126
# Epoch 2 Iteration 200: Loss = 0.1247873604297638, Number of mined triplets = 86
# Epoch 2 Iteration 220: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 240: Loss = 0.09950502961874008, Number of mined triplets = 65
# Epoch 2 Iteration 260: Loss = 0.11915101855993271, Number of mined triplets = 59
# Epoch 2 Iteration 280: Loss = 0.1087096631526947, Number of mined triplets = 19
# Epoch 2 Iteration 300: Loss = 0.09957077354192734, Number of mined triplets = 60
# Epoch 2 Iteration 320: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 340: Loss = 0.10725420713424683, Number of mined triplets = 12
# Epoch 2 Iteration 360: Loss = 0.105873703956604, Number of mined triplets = 90
# Epoch 2 Iteration 380: Loss = 0.12216786295175552, Number of mined triplets = 30
# Epoch 2 Iteration 400: Loss = 0.10407014191150665, Number of mined triplets = 161
# Epoch 2 Iteration 420: Loss = 0.11119070649147034, Number of mined triplets = 170
# Epoch 2 Iteration 440: Loss = 0.12449094653129578, Number of mined triplets = 37
# Epoch 2 Iteration 460: Loss = 0.09298042953014374, Number of mined triplets = 113
# Epoch 2 Iteration 480: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 500: Loss = 0.12624311447143555, Number of mined triplets = 77
# Epoch 2 Iteration 520: Loss = 0.09736236929893494, Number of mined triplets = 27
# Epoch 2 Iteration 540: Loss = 0.10934493690729141, Number of mined triplets = 46
# Epoch 2 Iteration 560: Loss = 0.10219988226890564, Number of mined triplets = 110
# Epoch 2 Iteration 580: Loss = 0.1259952038526535, Number of mined triplets = 38
# Epoch 2 Iteration 600: Loss = 0.12697218358516693, Number of mined triplets = 22
# Epoch 2 Iteration 620: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 640: Loss = 0.13523785769939423, Number of mined triplets = 85
# Epoch 2 Iteration 660: Loss = 0.15253916382789612, Number of mined triplets = 36
# Epoch 2 Iteration 680: Loss = 0.1489434540271759, Number of mined triplets = 39
# Epoch 2 Iteration 700: Loss = 0.11449608951807022, Number of mined triplets = 68
# Epoch 2 Iteration 720: Loss = 0.11587552726268768, Number of mined triplets = 96
# Epoch 2 Iteration 740: Loss = 0.13120892643928528, Number of mined triplets = 98
# Epoch 2 Iteration 760: Loss = 0.10950267314910889, Number of mined triplets = 83
# Epoch 2 Iteration 780: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration
Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 1760: Loss = 0.0849270150065422, Number of mined triplets = 25
# Epoch 2 Iteration 1780: Loss = 0.10371758788824081, Number of mined triplets = 32
# Epoch 2 Iteration 1800: Loss = 0.0836392417550087, Number of mined triplets = 28
# Epoch 2 Iteration 1820: Loss = 0.1171550527215004, Number of mined triplets = 115
# Epoch 2 Iteration 1840: Loss = 0.1397169828414917, Number of mined triplets = 65
# Epoch 2 Iteration 1860: Loss = 0.10262718051671982, Number of mined triplets = 32
# Epoch 2 Iteration 1880: Loss = 0.12315727770328522, Number of mined triplets = 16
# Epoch 2 Iteration 1900: Loss = 0.14127087593078613, Number of mined triplets = 158
# Epoch 2 Iteration 1920: Loss = 0.11645571887493134, Number of mined triplets = 48
# Epoch 2 Iteration 1940: Loss = 0.09458091109991074, Number of mined triplets = 40
# Epoch 2 Iteration 1960: Loss = 0.08953001350164413, Number of mined triplets = 39
# Epoch 2 Iteration 1980: Loss = 0.14256499707698822, Number of mined triplets = 26
# Epoch 2 Iteration 2000: Loss = 0.12766918540000916, Number of mined triplets = 172
# Epoch 2 Iteration 2020: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 2040: Loss = 0.11006789654493332, Number of mined triplets = 148
# Epoch 2 Iteration 2060: Loss = 0.1255045086145401, Number of mined triplets = 195
# Epoch 2 Iteration 2080: Loss = 0.19919903576374054, Number of mined triplets = 5
# Epoch 2 Iteration 2100: Loss = 0.12047989666461945, Number of mined triplets = 45
# Epoch 2 Iteration 2120: Loss = 0.13346412777900696, Number of mined triplets = 46
# Epoch 2 Iteration 2140: Loss = 0.1209493950009346, Number of mined triplets = 135
# Epoch 2 Iteration 2160: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 2180: Loss = 0.10504370182752609, Number of mined triplets = 59
# Epoch 2 Iteration 2200: Loss = 0.1275947093963623, Number of mined triplets = 136
# Epoch 2 Iteration 2220: Loss = 0.1174032986164093, Number of mined triplets = 43
# Epoch 2 Iteration 2240: Loss = 0.13030563294887543, Number of mined triplets = 185
# Epoch 2 Iteration 2260: Loss = 0.10140683501958847, Number of mined triplets = 47
# Epoch 2 Iteration 2280: Loss = 0.10164885222911835, Number of mined triplets = 24
# Epoch 2 Iteration 2300: Loss = 0.10618966817855835, Number of mined triplets = 72
# Epoch 2 Iteration 2320: Loss = 0.11672671884298325, Number of mined triplets = 83
# Epoch 2 Iteration 2340: Loss = 0.12466556578874588, Number of mined triplets = 11
# Epoch 2 Iteration 2360: Loss = 0.0894714742898941, Number of mined triplets = 26
# Epoch 2 Iteration 2380: Loss = 0.0769152119755745, Number of mined triplets = 35
# Epoch 2 Iteration 2400: Loss = 0.1295417845249176, Number of mined triplets = 137
# Epoch 2 Iteration 2420: Loss = 0.11032436043024063, Number of mined triplets = 175
# Epoch 2 Iteration 2440: Loss = 0.12373726814985275, Number of mined triplets = 57
# Epoch 2 Iteration 2460: Loss = 0.1015179380774498, Number of mined triplets = 24
# Epoch 2 Iteration 2480: Loss = 0.0, Number of mined triplets = 0
# Epoch 2 Iteration 2500: Loss = 0.12034812569618225, Number of mined triplets = 90
# Epoch 2 Iteration 2520: Loss = 0.127278670668602, Number of mined triplets = 18
# Epoch 2 Iteration 2540: Loss = 0.15069717168807983, Number of mined triplets = 59
# Epoch 2 Iteration 2560: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 0: Loss = 0.13372774422168732, Number of mined triplets = 94
# Epoch 3 Iteration 20: Loss = 0.11029905825853348, Number of mined triplets = 19
# Epoch 3 Iteration 40: Loss = 0.0929071381688118, Number of mined triplets = 21
# Epoch 3 Iteration 60: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 80: Loss = 0.12088537961244583, Number of mined triplets = 171
# Epoch 3 Iteration 100: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 120: Loss = 0.10003077983856201, Number of mined triplets = 27
# Epoch 3 Iteration 140: Loss = 0.1051751971244812, Number of mined triplets = 44
# Epoch 3 Iteration 160: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 180: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 200: Loss = 0.1400986611843109, Number of mined triplets = 149
# Epoch 3 Iteration 220: Loss = 0.14015430212020874, Number of mined triplets = 68
# Epoch 3 Iteration 240: Loss = 0.12765154242515564, Number of mined triplets = 172
# Epoch 3 Iteration 260: Loss = 0.12073241919279099, Number of mined triplets = 45
# Epoch 3 Iteration 280: Loss = 0.12066762149333954, Number of mined triplets = 12
# Epoch 3 Iteration 300: Loss = 0.12340071052312851, Number of mined triplets = 38
# Epoch 3 Iteration 320: Loss = 0.11523784697055817, Number of mined triplets = 78
# Epoch 3 Iteration 340: Loss = 0.11362037062644958, Number of mined triplets = 59
# Epoch 3 Iteration 360: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 380: Loss = 0.11908213049173355, Number of mined triplets = 56
# Epoch 3 Iteration 400: Loss = 0.10846203565597534, Number of mined triplets = 76
# Epoch 3 Iteration 420: Loss = 0.11291152238845825, Number of mined triplets = 62
# Epoch 3 Iteration 440: Loss = 0.11816076934337616, Number of mined triplets = 193
# Epoch 3 Iteration 460: Loss = 0.11952850222587585, Number of mined triplets = 39
# Epoch 3 Iteration 480: Loss = 0.1070847287774086, Number of mined triplets = 152
# Epoch 3 Iteration 500: Loss = 0.11935631930828094, Number of mined triplets = 127
# Epoch 3 Iteration 520: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 540: Loss = 0.08182087540626526, Number of mined triplets = 25
# Epoch 3 Iteration 560: Loss = 0.09868654608726501, Number of mined triplets = 109
# Epoch 3 Iteration 580: Loss = 0.1225707158446312, Number of mined triplets = 49
# Epoch 3 Iteration 600: Loss = 0.14195425808429718, Number of mined triplets = 103
# Epoch 3 Iteration 620: Loss = 0.15394684672355652, Number of mined triplets = 154
# Epoch 3 Iteration 640: Loss = 0.09275895357131958, Number of mined triplets = 65
# Epoch 3 Iteration 660: Loss = 0.14065462350845337, Number of mined triplets = 42
# Epoch 3 Iteration 680: Loss = 0.10367351025342941, Number of mined triplets = 33
# Epoch 3 Iteration 700: Loss = 0.13438205420970917, Number of mined triplets = 73
# Epoch 3 Iteration 720: Loss = 0.10574118047952652, Number of mined triplets = 27
# Epoch 3 Iteration 740: Loss = 0.12375735491514206, Number of mined triplets = 151
# Epoch 3 Iteration 760: Loss = 0.1563299596309662, Number of mined triplets = 64
# Epoch 3 Iteration 780: Loss = 0.11054500937461853, Number of mined triplets = 67
# Epoch 3 Iteration 800: Loss = 0.12972591817378998, Number of mined triplets = 71
# Epoch 3 Iteration 820: Loss = 0.11091059446334839, Number of mined triplets = 38
# Epoch 3 Iteration 840: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 860: Loss = 0.11636755615472794, Number of mined triplets = 141
# Epoch 3 Iteration 880: Loss = 0.12106888741254807, Number of mined triplets = 81
# Epoch 3 Iteration 900: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 920: Loss = 0.12274963408708572, Number of mined triplets = 79
# Epoch 3 Iteration 940: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 960: Loss = 0.12446849793195724, Number of mined triplets = 47
# Epoch 3 Iteration 980: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1000: Loss = 0.12883859872817993, Number of mined triplets = 140
# Epoch 3 Iteration 1020: Loss = 0.08952130377292633, Number of mined triplets = 46
# Epoch 3 Iteration 1040: Loss = 0.14237742125988007, Number of mined triplets = 90
# Epoch 3 Iteration 1060: Loss = 0.09790323674678802, Number of mined triplets = 68
# Epoch 3 Iteration 1080: Loss = 0.12155745923519135, Number of mined triplets = 120
# Epoch 3 Iteration 1100: Loss = 0.10782769322395325, Number of mined triplets = 81
# Epoch 3 Iteration 1120: Loss = 0.1253190040588379, Number of mined triplets = 38
# Epoch 3 Iteration 1140: Loss = 0.11034439504146576, Number of mined triplets = 35
# Epoch 3 Iteration 1160: Loss = 0.09721291810274124, Number of mined triplets = 59
# Epoch 3 Iteration 1180: Loss = 0.12827885150909424, Number of mined triplets = 23
# Epoch 3 Iteration 1200: Loss = 0.12118206918239594, Number of mined triplets = 56
# Epoch 3 Iteration 1220: Loss = 0.10664144903421402, Number of mined triplets = 65
# Epoch 3 Iteration 1240: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1260: Loss = 0.1243131160736084, Number of mined triplets = 12
# Epoch 3 Iteration 1280: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1300: Loss = 0.10163456946611404, Number of mined triplets = 21
# Epoch 3 Iteration 1320: Loss = 0.10143769532442093, Number of mined triplets = 109
# Epoch 3 Iteration 1340: Loss = 0.12437595427036285, Number of mined triplets = 66
# Epoch 3 Iteration 1360: Loss = 0.10575104504823685, Number of mined triplets = 103
# Epoch 3 Iteration 1380: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1400: Loss = 0.10381883382797241, Number of mined triplets = 40
# Epoch 3 Iteration 1420: Loss = 0.09667793661355972, Number of mined triplets = 58
# Epoch 3 Iteration 1440: Loss = 0.09410595893859863, Number of mined triplets = 65
# Epoch 3 Iteration 1460: Loss = 0.15239150822162628, Number of mined triplets = 119
# Epoch 3 Iteration 1480: Loss = 0.16028420627117157, Number of mined triplets = 144
# Epoch 3 Iteration 1500: Loss = 0.1311275064945221, Number of mined triplets = 50
# Epoch 3 Iteration 1520: Loss = 0.18207038938999176, Number of mined triplets = 9
# Epoch 3 Iteration 1540: Loss = 0.13327743113040924, Number of mined triplets = 91
# Epoch 3 Iteration 1560: Loss = 0.11678531765937805, Number of mined triplets = 92
# Epoch 3 Iteration 1580: Loss = 0.10245157033205032, Number of mined triplets = 86
# Epoch 3 Iteration 1600: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1620: Loss = 0.09303002059459686, Number of mined triplets = 57
# Epoch 3 Iteration 1640: Loss = 0.11665729433298111, Number of mined triplets = 84
# Epoch 3 Iteration 1660: Loss = 0.1040503978729248, Number of mined triplets = 48
# Epoch 3 Iteration 1680: Loss = 0.09723450988531113, Number of mined triplets = 24
# Epoch 3 Iteration 1700: Loss = 0.11604666709899902, Number of mined triplets = 61
# Epoch 3 Iteration 1720: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1740: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1760: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1780: Loss = 0.18909385800361633, Number of mined triplets = 14
# Epoch 3 Iteration 1800: Loss = 0.09793933480978012, Number of mined triplets = 63
# Epoch 3 Iteration 1820: Loss = 0.10582409054040909, Number of mined triplets = 14
# Epoch 3 Iteration 1840: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 1860: Loss = 0.12016534060239792, Number of mined triplets = 45
# Epoch 3 Iteration 1880: Loss = 0.11811399459838867, Number of mined triplets = 28
# Epoch 3 Iteration 1900: Loss = 0.09203453361988068, Number of mined triplets = 133
# Epoch 3 Iteration 1920: Loss = 0.11721756309270859, Number of mined triplets = 13
# Epoch 3 Iteration 1940: Loss = 0.11878453195095062, Number of mined triplets = 51
# Epoch 3 Iteration 1960: Loss = 0.12839433550834656, Number of mined triplets = 76
# Epoch 3 Iteration 1980: Loss = 0.10423148423433304, Number of mined triplets = 27
# Epoch 3 Iteration 2000: Loss = 0.12511609494686127, Number of mined triplets = 127
# Epoch 3 Iteration 2020: Loss = 0.11268738657236099, Number of mined triplets = 69
# Epoch 3 Iteration 2040: Loss = 0.08281753957271576, Number of mined triplets = 18
# Epoch 3 Iteration 2060: Loss = 0.10699017345905304, Number of mined triplets = 56
# Epoch 3 Iteration 2080: Loss = 0.14384087920188904, Number of mined triplets = 56
# Epoch 3 Iteration 2100: Loss = 0.10427640378475189, Number of mined triplets = 17
# Epoch 3 Iteration 2120: Loss = 0.1101117879152298, Number of mined triplets = 28
# Epoch 3 Iteration 2140: Loss = 0.08998221904039383, Number of mined triplets = 62
# Epoch 3 Iteration 2160: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 2180: Loss = 0.1344592124223709, Number of mined triplets = 54
# Epoch 3 Iteration 2200: Loss = 0.12172940373420715, Number of mined triplets = 110
# Epoch 3 Iteration 2220: Loss = 0.15090937912464142, Number of mined triplets = 86
# Epoch 3 Iteration 2240: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 2260: Loss = 0.13243255019187927, Number of mined triplets = 50
# Epoch 3 Iteration 2280: Loss = 0.11701104044914246, Number of mined triplets = 58
# Epoch 3 Iteration 2300: Loss = 0.0, Number of mined triplets = 0
# Epoch 3 Iteration 2320: Loss = 0.09251804649829865, Number of mined triplets = 31
# Epoch 3 Iteration 2340: Loss = 0.12275579571723938, Number of mined triplets = 72
# Epoch 3 Iteration 2360: Loss = 0.1251371204853058, Number of mined triplets = 119
# Epoch 3 Iteration 2380: Loss = 0.10930660367012024, Number of mined triplets = 56
# Epoch 3 Iteration 2400: Loss = 0.12144754081964493, Number of mined triplets = 143
# Epoch 3 Iteration 2420: Loss = 0.1172473356127739, Number of mined triplets = 92
# Epoch 3 Iteration 2440: Loss = 0.14336612820625305, Number of mined triplets = 57
# Epoch 3 Iteration 2460: Loss = 0.12025731801986694, Number of mined triplets = 105
# Epoch 3 Iteration 2480: Loss = 0.12379052489995956, Number of mined triplets = 121
# Epoch 3 Iteration 2500: Loss = 0.13172240555286407, Number of mined triplets = 78
# Epoch 3 Iteration 2520: Loss = 0.13297298550605774, Number of mined triplets = 52
# Epoch 3 Iteration 2540: Loss = 0.10095680505037308, Number of mined triplets = 13
# Epoch 3 Iteration 2560: Loss = 0.0, Number of mined triplets = 0
