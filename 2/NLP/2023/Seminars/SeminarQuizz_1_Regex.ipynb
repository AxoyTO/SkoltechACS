# %% [markdown]
# # Task: detection of date, time, phone, and addresses
#
# 0. Load text from wikitext dataset as shown below
#
# 1. Write a regexps/grammars for detection of dates, times, phones, and addresses
#
# 2. Save list of the found entities into a text file indicating type in the format "entity\<TAB\>type" where type is in {date, time, phone, address}
#
# 3. Count the number of the found entries and print top 20 for each category in the form of the table with frequencies "entity\<TAB\>entity-type\<TAB\>frequency" sorted by frequency
#
# Examples:
#
# - date: 01.01.2000 or 1st of January 2000
# - time: 7pm or 19:00
# - phone: 89163700033 or +7 (916) 370-00-33
# - address: Bolshoy Boulevard, 30, p.1, Moscow 121205, Russia
#
# # How to proceed:
#
# 1. You can use regex or yargy to build your own "hand-made" solution (mandatory)
#
# 2. In addition to the hand-made solution (regex, yargy, ...) you can also implement alternative solution with pre-exising models for NER to get a higher point

# %%
! pip install  datasets

# %%
from datasets import load_dataset

dataset = load_dataset("wikitext", "wikitext-2-v1")
# Out:
# ...
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 36718
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })

# %%
# Write your code here

for i, t in enumerate(dataset["train"]):
  line = t["text"]
  # write code for detection of entities and saving them into files
  if "2001" in line:
    print(line)
# Out:
#  The Tower Building of the Little Rock Arsenal , also known as U.S. Arsenal Building , is a building located in MacArthur Park in downtown Little Rock , Arkansas . Built in 1840 , it was part of Little Rock 's first military installation . Since its decommissioning , The Tower Building has housed two museums . It was home to the Arkansas Museum of Natural History and Antiquities from 1942 to 1997 and the MacArthur Museum of Arkansas Military History since 2001 . It has also been the headquarters of the Little Rock Æsthetic Club since 1894 .
#
# ...

# %% [markdown]
# from datasets import load_dataset
