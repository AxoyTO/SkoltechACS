# %% [markdown]
# # 01 Introduction to Python: EDA 101

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# A workhorse of scientific visualization in Python.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# [deprecated] Set figure appearance in notebook (no pop up).
#
# ```ipython
# %matplotlib inline
# ```

# %% [markdown]
# ### Line Plot

# %% [markdown]
# Draw a line plot of a function
#
# $$
#     y = x ^2
# $$
#
# for $x$ from -1 to 1.

# %%
xs = np.linspace(-1, 1, 101)
ys = xs ** 2

# %%
plt.plot(xs, ys, color='#ff00ff', label='$x^2$')
plt.legend()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 4), layout='constrained')

ax = axs[1]
ax.plot(xs, ys, marker='.', label=r'$x^2$')
ax.plot(xs, np.sqrt(ys), marker='.', label=r'$\sqrt{x^2}$')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show()

# %% [markdown]
# ### Histogram

# %%
cats = np.random.randint(low=0, high=10, size=1000)
len(cats)
# Out:
# 1000

# %%
plt.hist(cats, bins=10, range=(0, 10), width=1.0)
plt.xlabel('Number')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Bar Plot

# %%
counts = np.bincount(cats)
counts
# Out:
# array([ 95, 110, 106,  90,  95, 108,  86, 113, 101,  96], dtype=int64)

# %%
numbers = np.arange(10)

# %%
plt.bar(numbers, counts)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# Let's generate random points on a 2D plane and plot them.

# %%
n_points = 100
n_dims = 2

# %%
xs = np.random.normal(loc=0.0, scale=1.0, size=(n_points, n_dims))
xs.shape
# Out:
# (100, 2)

# %%
xs[:5]
# Out:
# array([[-0.24751923, -0.45312679],
#        [-0.1709767 , -0.14961945],
#        [ 0.52832823, -0.62205278],
#        [ 0.77611668, -1.15058085],
#        [-0.79911182,  0.16234456]])

# %%
xs[:5, 0]
# Out:
# array([-0.24751923, -0.1709767 ,  0.52832823,  0.77611668, -0.79911182])

# %%
xs[:5, 1]
# Out:
# array([-0.45312679, -0.14961945, -0.62205278, -1.15058085,  0.16234456])

# %%
plt.scatter(xs[:, 0], xs[:, 1], s=100, c='magenta', edgecolors='black')

# %% [markdown]
# ## Sklearn

# %% [markdown]
# ### Toy Problem
#
# Let's solve a toy problem on a synthetic dataset.
#
# 1. Generate synthetic dataset.
# 2. Build a model.
# 3. Train a model.
# 4. Evaluate a model.
# 5. Select best model.

# %% [markdown]
# #### Synthetic data

# %%
from sklearn.datasets import make_moons

# %%
xs, ys = make_moons(n_samples=200, noise=0.1)

# %%
xs[:5]
# Out:
# array([[ 1.0360954 ,  0.20193637],
#        [ 1.97031899,  0.18717007],
#        [-0.99726449,  0.43825   ],
#        [ 2.23028192,  0.50770645],
#        [-0.70995277,  0.52101958]])

# %%
ys[:5]
# Out:
# array([0, 1, 0, 1, 0], dtype=int64)

# %%
xs1 = xs[ys == 0]
xs1.shape
# Out:
# (100, 2)

# %%
xs2 = xs[ys == 1]
xs2.shape
# Out:
# (100, 2)

# %%
plt.scatter(xs1[:, 0], xs1[:, 1], label='moon')
plt.scatter(xs2[:, 0], xs2[:, 1], label='dojo cat')
plt.legend()

# %% [markdown]
# #### Toy classifier
#
# Train and evaluate a classifier.

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Every algorithm from `sklearn` has a set of parameters which could be specified on an instantiation of an estimator.

# %%
clf = LogisticRegression(C=1.0)

# %% [markdown]
# Every algorithm has a method `fit`.
#
# ```
# Signature: estimator.fit(X, y)
#
# Parameters
# ----------
# X : {array-like} of shape (n_samples, n_features)
#     Training vectors, where `n_samples` is the number of samples
#     and `n_features` is the number of features..
#
# y : array-like of shape (n_samples,)
#     Target values or classes.
# ```

# %%
xs.shape
# Out:
# (200, 2)

# %%
features.shape
# Out:
# (200, 2)

# %%
labels.shape
# Out:
# (200,)

# %%
ys.shape
# Out:
# (200,)

# %%
features = xs
labels = ys
clf.fit(features, labels);

# %% [markdown]
# A classifier/regressor in `sklearn` usually has a method `.predict()` which calculates predictions.

# %%
preds = clf.predict(features)

# %%
def vis(ax: plt.Axes, xs, ys):
    print(len(xs), len(ys))
    return ax.scatter(xs, ys)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
vis(axs[0], features, labels)
vis(axs[1], features, preds)
plt.show()
# Out:
# 200 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
# ----> 2 vis(axs[0], features, labels)
#       3 vis(axs[1], features, preds)
#       4 plt.show()
#
# Cell In[50], line 3, in vis(ax, xs, ys)
#       1 def vis(ax: plt.Axes, xs, ys):
#       2     print(len(xs), len(ys))
# ----> 3     return ax.scatter(xs, ys)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:4584, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582 y = np.ma.ravel(y)
#    4583 if x.size != y.size:
# -> 4584     raise ValueError("x and y must be the same size")
#    4586 if s is None:
#    4587     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4588          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %% [markdown]
# ### Accuracy

# %% [markdown]
# Let's estimate how accurate our model are. The simplest meature is _accuracy_ metric which is defined as follows.
#
# $$
#     accuracy = \frac{1}{N} \sum_k^N [y^{(k)}_{true} == y^{(k)}_{pred}]
# $$
#
# It basically says what percent of target labels we predicted correctly.

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(labels, preds)
# Out:
# 0.87

# %%
from sklearn.metrics import classification_report

# %%
classification_report(labels, preds)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.86      0.88      0.87       100\n           1       0.88      0.86      0.87       100\n\n    accuracy                           0.87       200\n   macro avg       0.87      0.87      0.87       200\nweighted avg       0.87      0.87      0.87       200\n'

# %% [markdown]
# ### Model Selection

# %% [markdown]
# We onl

# %% [markdown]
# ![Train, test, and validation data split][1]
#
# [1]: train-test-val.png

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.25)

# %%
X_train.shape
# Out:
# (150, 2)

# %%
y_train.shape
# Out:
# (150,)

# %%
X_test.shape
# Out:
# (50, 2)

# %%
y_test.shape
# Out:
# (50,)

# %%
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
from sklearn.model_selection import cross_validate

# %%
cv = cross_validate(clf, features, labels, cv=4, scoring=['accuracy', 'precision', 'recall'])
cv
# Out:
# {'fit_time': array([0.00096679, 0.00100112, 0.00097489, 0.        ]),
#  'score_time': array([0.00199986, 0.00099945, 0.00100183, 0.00200033]),
#  'test_accuracy': array([0.88, 0.94, 0.82, 0.78]),
#  'test_precision': array([0.82758621, 0.95833333, 0.9       , 0.76923077]),
#  'test_recall': array([0.96, 0.92, 0.72, 0.8 ])}

# %% [markdown]
# ##### Bridging to `pandas`

# %% [markdown]
# Dictionary is not very convinient for post processing of data. Let's convert it to `pandas.DataFraem` and make couple of tricks.

# %%
import pandas as pd

# %%
df = pd.DataFrame(cv)
df
# Out:
#    fit_time  score_time  test_accuracy  test_precision  test_recall
# 0  0.000967    0.002000           0.88        0.827586         0.96
# 1  0.001001    0.000999           0.94        0.958333         0.92
# 2  0.000975    0.001002           0.82        0.900000         0.72
# 3  0.000000    0.002000           0.78        0.769231         0.80

# %%
df = df[df.columns[2:]]
df
# Out:
#    test_accuracy  test_precision  test_recall
# 0           0.88        0.827586         0.96
# 1           0.94        0.958333         0.92
# 2           0.82        0.900000         0.72
# 3           0.78        0.769231         0.80

# %%
df.mean()
# Out:
# test_accuracy     0.855000
# test_precision    0.863788
# test_recall       0.850000
# dtype: float64

# %% [markdown]
# ## Pandas
#
# The most usefull and commonly used library for tabular data.

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.github.com/mattdelhey/kaggle-titanic/master/Data/train.csv'

# %%
titanic = pd.read_csv(url)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.sort_values(by='age', ascending=False).head(5)
# Out:
#      survived  pclass                                  name   sex   age  \
# 630         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851         0       3                   Svensson, Mr. Johan  male  74.0
# 493         0       1               Artagaveytia, Mr. Ramon  male  71.0
# 96          0       1             Goldschmidt, Mr. George B  male  71.0
# 116         0       3                  Connors, Mr. Patrick  male  70.5
#
#      sibsp  parch    ticket     fare cabin embarked
# 630      0      0     27042  30.0000   A23        S
# 851      0      0    347060   7.7750   NaN        S
# 493      0      0  PC 17609  49.5042   NaN        C
# 96       0      0  PC 17754  34.6542    A5        C
# 116      0      0    370369   7.7500   NaN        Q

# %% [markdown]
# Indexing can be tricky.

# %%
titanic[['age', 'name']].head(5)
# Out:
#     age                                               name
# 0  22.0                            Braund, Mr. Owen Harris
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0                             Heikkinen, Miss. Laina
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0                           Allen, Mr. William Henry

# %%
titanic.iloc[[2, 5, 6], 2:5]
# Out:
#                       name     sex   age
# 2   Heikkinen, Miss. Laina  female  26.0
# 5         Moran, Mr. James    male   NaN
# 6  McCarthy, Mr. Timothy J    male  54.0

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# You can extract a numpy array

# %%
type(titanic.values)  # depracted
type(titanic.to_numpy())
# Out:
# numpy.ndarray

# %%
titanic.age.to_numpy()[:10]
# Out:
# array([22., 38., 26., 35., 35., nan, 54.,  2., 27., 14.])

# %%
titanic.age.to_numpy().shape
# Out:
# (891,)

# %% [markdown]
# See more details here: 10 Minutes to pandas (actually it requires much more)
#
# http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# ## Seaborn
#
# A high-level library for visualization and exploratory data analysis.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\toaxo\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\toaxo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
# sns.set() allows to use a more attractive color scheme for plots
sns.set()

# %%
sns.catplot(x="pclass", kind="count", data=titanic)

# %%
sns.catplot(titanic, x="pclass", hue="sex", kind="count")

# %%
fg = sns.FacetGrid(titanic, hue="sex", aspect=3)
fg.map(sns.kdeplot, "age", fill=True)
fg.set(xlim=(0, 80));

# %%
fg = sns.FacetGrid(titanic, col="sex", row="pclass", hue="sex", height=2.5, aspect=2.5)
fg.map(sns.kdeplot, "age", fill=True)
fg.map(sns.rugplot, "age")
sns.despine(left=True)
fg.set(xlim=(0, 80));

# %% [markdown]
# Visualising the survival of passengers based on classes.

# %%
grid = sns.FacetGrid(titanic, col='survived', row='pclass', height=2.2, aspect=1.6)
grid.map(plt.hist, 'age', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# Visualising Class and Embarkment with Survivability.

# %%
grid = sns.FacetGrid(titanic, row ='embarked', height=4, aspect=3)
grid.map(sns.pointplot, 'pclass', 'survived', 'sex', palette='deep')
grid.add_legend()
# Out:
# C:\Users\toaxo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\toaxo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:717: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# See more example of Seaborn visualizations for the Titanic dataset here
#
# https://gist.github.com/mwaskom/8224591

# %% [markdown]
# ## Model Problem
#
# 1. Load data from the csv file.
# 2. Check column names.
# 3. Look for dependencies between features and the target vector.
#
# Public Kaggle competition is [here][1] (for those who want compete for fun).
#
# [1]: https://www.kaggle.com/competitions/titanic

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Let's do  little bit of processing to make some different variables that might be more interesting to plot. Since this notebook is focused on visualization, we're going to do this without much comment.

# %%
titanic = titanic.drop(['name', 'ticket', 'cabin'], axis=1)
titanic['sex'] = titanic.sex.map({'male': 0, 'female': 1})
titanic = pd.get_dummies(titanic, dummy_na=True, columns=['embarked'])
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked_C  embarked_Q  \
# 0         0       3    0  22.0      1      0   7.2500           0           0
# 1         1       1    1  38.0      1      0  71.2833           1           0
# 2         1       3    1  26.0      0      0   7.9250           0           0
# 3         1       1    1  35.0      1      0  53.1000           0           0
# 4         0       3    0  35.0      0      0   8.0500           0           0
#
#    embarked_S  embarked_nan
# 0           1             0
# 1           0             0
# 2           1             0
# 3           1             0
# 4           1             0

# %%
titanic.count()
# Out:
# survived        891
# pclass          891
# sex             891
# age             714
# sibsp           891
# parch           891
# fare            891
# embarked_C      891
# embarked_Q      891
# embarked_S      891
# embarked_nan    891
# dtype: int64

# %%
# titanic.dropna(inplace=True)
titanic = titanic.dropna()
titanic.head(6)
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked_C  embarked_Q  \
# 0         0       3    0  22.0      1      0   7.2500           0           0
# 1         1       1    1  38.0      1      0  71.2833           1           0
# 2         1       3    1  26.0      0      0   7.9250           0           0
# 3         1       1    1  35.0      1      0  53.1000           0           0
# 4         0       3    0  35.0      0      0   8.0500           0           0
# 6         0       1    0  54.0      0      0  51.8625           0           0
#
#    embarked_S  embarked_nan
# 0           1             0
# 1           0             0
# 2           1             0
# 3           1             0
# 4           1             0
# 6           1             0

# %%
titanic.count()
# Out:
# survived        714
# pclass          714
# sex             714
# age             714
# sibsp           714
# parch           714
# fare            714
# embarked_C      714
# embarked_Q      714
# embarked_S      714
# embarked_nan    714
# dtype: int64

# %% [markdown]
# Our target value is wheter passnager survice or not (`survived`). The rest of columns are features.

# %%
# extract X - features & y - targets
X = titanic.drop('survived', axis=1)
y = titanic.survived

# %% [markdown]
# #### Now it's time to build a model

# %%
# initialize a classifier
clf = KNeighborsClassifier()

# train the classifier
clf.fit(X, y)

# calculate predictions
y_predicted = clf.predict(X)

# estimate accuracy
print('Accuracy of prediction is {}'.format(np.mean(y == y_predicted)))
# Out:
# Accuracy of prediction is 0.7955182072829131

# %%
#you can also specify some parameters during initialization
clf = KNeighborsClassifier(n_neighbors=10)

clf.fit(X, y)
y_predicted = clf.predict(X)
print('Accuracy of prediction is {}'.format(np.mean(y == y_predicted)))
# Out:
# Accuracy of prediction is 0.742296918767507

# %%
# you can also predict probabilities of belonging to a particular class
proba = clf.predict_proba(X)
proba_df = pd.DataFrame(proba, index=y.index, columns=[0, 1])
proba_df['true'] = y

fg = sns.FacetGrid(proba_df, hue="true", aspect=3)
fg.map(sns.kdeplot, 0, fill=True)
plt.xlabel('Predicted probability of survivance')
plt.legend(['survived=0', 'survived=1'])
